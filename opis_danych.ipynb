# %% [markdown]
# <center><h1>Lab3</h1></center>
# <h4 style= "float:right">Wykonał: Krzysztof Przyszlak
# </h4>

# %%
import pandas as pd
df = pd.read_csv("dane_A.csv")
print(df.head())
# Out:
#    Entity Code  Year  \
# 0  Africa  NaN  1961
# 1  Africa  NaN  1962
# 2  Africa  NaN  1963
# 3  Africa  NaN  1964
# 4  Africa  NaN  1965
#
#    Coffee, green | 00000656 || Production | 005510 || tonnes
# 0                                           870970.0
# 1                                           883512.0
# 2                                           996674.0
# 3                                          1162048.0
# 4                                          1075084.0

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of         Entity Code  Year  \
# 0       Africa  NaN  1961
# 1       Africa  NaN  1962
# 2       Africa  NaN  1963
# 3       Africa  NaN  1964
# 4       Africa  NaN  1965
# ...        ...  ...   ...
# 7292  Zimbabwe  ZWE  2019
# 7293  Zimbabwe  ZWE  2020
# 7294  Zimbabwe  ZWE  2021
# 7295  Zimbabwe  ZWE  2022
# 7296  Zimbabwe  ZWE  2023
#
#       Coffee, green | 00000656 || Production | 005510 || tonnes
# 0                                             870970.00
# 1                                             883512.00
# 2                                             996674.00
# 3                                            1162048.00
# 4                                            1075084.00
# ...                                                 ...
# 7292                                             531.00
# 7293                                             579.00
# 7294                                             608.00
# ...

# %% [markdown]
# Dane_A.csv zawiera 29 188 rekordów<br>
# Dane dotyczą produkcji kawy w regionach w latach 1961-2023 podanej w tonach<br>
# Autor: Food and Agriculture Organization of the United Nations<br>
# Nazwa zbioru: Coffee production by region<br>
# Link: https://ourworldindata.org/grapher/coffee-production-by-region?tab=table

# %%
ds = pd.read_csv("dane_B.csv")
print(ds.head())
# Out:
#                             Country      Coffee type    1990/91    1991/92  \
# 0                            Angola  Robusta/Arabica    1200000    1800000
# 1  Bolivia (Plurinational State of)          Arabica    1500000    1620000
# 2                            Brazil  Arabica/Robusta  492000000  510000000
# 3                           Burundi  Arabica/Robusta     120000      96000
# 4                           Ecuador  Arabica/Robusta   21000000   21000000
#
#      1992/93    1993/94    1994/95    1995/96    1996/97    1997/98  ...  \
# 0    2100000    1200000    1500000     600000    1200000    2400000  ...
# 1    1650000    1710000    1770000    1830000    1890000    1950000  ...
# 2  534000000  546000000  558000000  606000000  660000000  690000000  ...
# 3     102000     114600     120000     120000     120000     120000  ...
# 4   21000000   21000000   21000000   21000000   18000000   18000000  ...
#
# ...

# %%
print(ds.describe)
# Out:
# <bound method NDFrame.describe of                              Country      Coffee type    1990/91    1991/92  \
# 0                             Angola  Robusta/Arabica    1200000    1800000
# 1   Bolivia (Plurinational State of)          Arabica    1500000    1620000
# 2                             Brazil  Arabica/Robusta  492000000  510000000
# 3                            Burundi  Arabica/Robusta     120000      96000
# 4                            Ecuador  Arabica/Robusta   21000000   21000000
# 5                          Indonesia  Robusta/Arabica   74520000   76800000
# 6                         Madagascar          Robusta   21000000   18000000
# 7                             Malawi          Arabica     120000     120000
# 8                   Papua New Guinea  Arabica/Robusta     180000     180000
# 9                           Paraguay          Arabica     900000     900000
# 10                              Peru          Arabica   11400000   11400000
# ...

# %% [markdown]
# Dane_B.csv zawiera 1 815 rekordów<br>
# Dane dotyczą spożycia kawy w regionach z podziałem na typ kawy podane w kg w latach 1990-2020<br>
# Autor: International Coffee Organization<br>
# Nazwa zbioru: Coffee economic indicatores<br>
# Link: https://www.kaggle.com/datasets/michals22/coffee-dataset?resource=download
